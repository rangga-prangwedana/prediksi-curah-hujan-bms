# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('data_prototype.csv')
dataset.head()
# Out:
#       Tanggal    Tn    Tx  Tavg   ss  ddd_x  ff_avg  N  NE  E  ...   RH3  \
# 0  06-02-2010  24.7  29.4  26.5  0.1  240.0     2.0  0   0  0  ...  80.0
# 1  07-02-2010  25.0  32.2  27.5  3.3  120.0     2.0  0   0  0  ...  85.0
# 2  08-02-2010  25.2  32.5  27.4  5.9  100.0     2.0  0   0  0  ...  83.0
# 3  09-02-2010  25.0  32.0  27.2  5.4  100.0     2.0  0   0  1  ...  81.0
# 4  10-02-2010  24.2  32.2  28.1  8.0  200.0     2.0  0   0  0  ...  82.0
#
#    RH_avg  ff_x1  ff_x2  ff_x3  ff_x   RR1       RR2       RR3        RR
# 0    85.0    7.0    9.0    9.0   7.0   2.5   0.80000   1.70000   0.20000
# 1    83.0    9.0    9.0    7.0   7.0   0.8   1.70000   0.20000  16.10000
# 2    81.0    9.0    7.0    7.0  10.0   1.7   0.20000  16.10000   8.33913
# 3    82.0    7.0    7.0   10.0   6.0   0.2  16.10000   8.33913   0.00000
# 4    82.0    7.0   10.0    6.0   7.0  16.1   8.33913   0.00000   7.70000
#
# [5 rows x 42 columns]

# %%
datades = dataset.describe()

# %%
datades.RR
# Out:
# count    2623.000000
# mean       12.673170
# std        19.986404
# min         0.000000
# 25%         0.200000
# 50%         5.300000
# 75%        17.266667
# max       199.500000
# Name: RR, dtype: float64

# %%
dmbn = np.asarray(datades.RR)

# %%
dmbn
# Out:
# array([2.62300000e+03, 1.26731697e+01, 1.99864045e+01, 0.00000000e+00,
#        2.00000000e-01, 5.30000000e+00, 1.72666667e+01, 1.99500000e+02])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2624 entries, 0 to 2623
# Data columns (total 42 columns):
# Tanggal        2624 non-null object
# Tn             2624 non-null float64
# Tx             2618 non-null float64
# Tavg           2624 non-null float64
# ss             2623 non-null float64
# ddd_x          2623 non-null float64
# ff_avg         2624 non-null float64
# N              2624 non-null int64
# NE             2624 non-null int64
# E              2624 non-null int64
# SE             2624 non-null int64
# S              2624 non-null int64
# SW             2624 non-null int64
# W              2624 non-null int64
# NW             2624 non-null int64
# C              2624 non-null int64
# Jan            2624 non-null int64
# Feb            2624 non-null int64
# Mar            2624 non-null int64
# Apr            2624 non-null int64
# Mei            2624 non-null int64
# Jun            2624 non-null int64
# Jul            2624 non-null int64
# ...

# %%
dataset.fillna(method = 'ffill', inplace = True)

# %%
dataset = dataset.drop(columns = ['ss','ff_avg','Tanggal'])

# %%
dataset.describe().T
# Out:
#               count        mean        std   min         25%         50%  \
# Tn           2624.0   24.508147   0.983965  19.5   24.000000   24.600000
# Tx           2624.0   30.966049   1.628616   3.6   30.000000   31.200000
# Tavg         2624.0   27.209915   1.081298  23.2   26.600000   27.400000
# ddd_x        2624.0  166.124615  66.797015  10.0  120.000000  140.000000
# N            2624.0    0.245046   0.430196   0.0    0.000000    0.000000
# NE           2624.0    0.002668   0.051591   0.0    0.000000    0.000000
# E            2624.0    0.211890   0.408725   0.0    0.000000    0.000000
# SE           2624.0    0.263720   0.440733   0.0    0.000000    0.000000
# S            2624.0    0.029726   0.169862   0.0    0.000000    0.000000
# SW           2624.0    0.034299   0.182030   0.0    0.000000    0.000000
# W            2624.0    0.136052   0.342909   0.0    0.000000    0.000000
# NW           2624.0    0.031631   0.175049   0.0    0.000000    0.000000
# ...

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.61904762, 0.81388013, 0.45205479, ..., 0.00401003, 0.0085213 ,
#         0.00100251],
#        [0.6547619 , 0.9022082 , 0.5890411 , ..., 0.0085213 , 0.00100251,
#         0.08070175],
#        [0.67857143, 0.91167192, 0.57534247, ..., 0.00100251, 0.08070175,
#         0.04180015],
#        ...,
#        [0.6547619 , 0.84542587, 0.61643836, ..., 0.00250627, 0.05635517,
#         0.00200501],
#        [0.6792328 , 0.87132658, 0.64535769, ..., 0.05635517, 0.00200501,
#         0.05635517],
#        [0.6792328 , 0.88328076, 0.60273973, ..., 0.00200501, 0.05635517,
#         0.05635517]])

# %%
dataset.columns
# Out:
# Index(['Tn', 'Tx', 'Tavg', 'ddd_x', 'N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW',
#        'C', 'Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Ags', 'Sep',
#        'Okt', 'Nov', 'Des', 'RR_avg_5day', 'RH_avg_5day', 'RH1', 'RH2', 'RH3',
#        'RH_avg', 'ff_x1', 'ff_x2', 'ff_x3', 'ff_x', 'RR1', 'RR2', 'RR3', 'RR'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
#Buat split data
#Buat X yg di drop yang target, y jadi target

y = dataset_scaled[:,38]
X = np.delete(dataset_scaled,38,axis=1)

# %%
X
# Out:
# array([[0.61904762, 0.81388013, 0.45205479, ..., 0.01253133, 0.00401003,
#         0.0085213 ],
#        [0.6547619 , 0.9022082 , 0.5890411 , ..., 0.00401003, 0.0085213 ,
#         0.00100251],
#        [0.67857143, 0.91167192, 0.57534247, ..., 0.0085213 , 0.00100251,
#         0.08070175],
#        ...,
#        [0.6547619 , 0.84542587, 0.61643836, ..., 0.05635517, 0.00250627,
#         0.05635517],
#        [0.6792328 , 0.87132658, 0.64535769, ..., 0.00250627, 0.05635517,
#         0.00200501],
#        [0.6792328 , 0.88328076, 0.60273973, ..., 0.05635517, 0.00200501,
#         0.05635517]])

# %%
dataset_scaled.shape
# Out:
# (2624, 39)

# %%
y
# Out:
# array([0.00100251, 0.08070175, 0.04180015, ..., 0.00200501, 0.05635517,
#        0.05635517])

# %%
X0 = X_scaled.to_numpy()
y0 = y_scaled.to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
X_train
# Out:
# array([[0.75      , 0.88958991, 0.71232877, ..., 0.00501253, 0.24611529,
#         0.00501253],
#        [0.53571429, 0.87697161, 0.52054795, ..., 0.01002506, 0.25413534,
#         0.        ],
#        [0.57142857, 0.87066246, 0.47945205, ..., 0.16090226, 0.16390977,
#         0.04711779],
#        ...,
#        [0.60714286, 0.82649842, 0.50684932, ..., 0.        , 0.01455562,
#         0.00601504],
#        [0.51190476, 0.90851735, 0.7260274 , ..., 0.17042607, 0.02706767,
#         0.        ],
#        [0.53571429, 0.84858044, 0.52054795, ..., 0.        , 0.        ,
#         0.        ]])

# %%
X_test
# Out:
# array([[0.53571429, 0.87697161, 0.54794521, ..., 0.06766917, 0.10776942,
#         0.01152882],
#        [0.5952381 , 0.89905363, 0.63013699, ..., 0.11177945, 0.01704261,
#         0.11060003],
#        [0.64285714, 0.89274448, 0.63013699, ..., 0.10426065, 0.0556391 ,
#         0.13132832],
#        ...,
#        [0.6547619 , 0.87697161, 0.5890411 , ..., 0.01754386, 0.1112782 ,
#         0.01804511],
#        [0.6547619 , 0.9148265 , 0.69863014, ..., 0.09118033, 0.04962406,
#         0.00651629],
#        [0.77380952, 0.95268139, 0.90410959, ..., 0.03802363, 0.        ,
#         0.        ]])

# %%
y_train
# Out:
# array([0.05864662, 0.        , 0.        , ..., 0.00902256, 0.00100251,
#        0.11177945])

# %%
y_test
# Out:
# array([6.66666667e-02, 1.69423559e-01, 8.37092732e-02, 1.73934837e-01,
#        1.04260652e-01, 1.00250627e-03, 3.11278195e-01, 0.00000000e+00,
#        4.28129146e-02, 5.51378446e-03, 8.81847476e-02, 2.50626566e-02,
#        6.46616541e-02, 0.00000000e+00, 1.03583960e-01, 9.66363277e-02,
#        4.03007519e-01, 7.59085213e-02, 0.00000000e+00, 1.42333105e-01,
#        1.54385965e-01, 0.00000000e+00, 4.11528822e-01, 1.57393484e-01,
#        5.01253133e-03, 2.80200501e-01, 1.21514312e-01, 1.42333105e-01,
#        3.80952381e-02, 8.02005013e-02, 0.00000000e+00, 5.41353383e-02,
#        0.00000000e+00, 3.00751880e-03, 6.51629073e-03, 0.00000000e+00,
#        1.51879699e-01, 4.93506494e-02, 1.21514312e-01, 0.00000000e+00,
#        1.00250627e-03, 7.61904762e-02, 1.12820513e-01, 0.00000000e+00,
#        0.00000000e+00, 2.96195033e-04, 1.15288221e-02, 4.56140351e-01,
#        6.92024178e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X_train.shape
# Out:
# (2099, 38)

# %%
X_train.shape[0]
# Out:
# 2099

# %%
abc = np.reshape(X_train,(2099,1,38))

# %%
abc
# Out:
# array([[[0.75      , 0.88958991, 0.71232877, ..., 0.00501253,
#          0.24611529, 0.00501253]],
#
#        [[0.53571429, 0.87697161, 0.52054795, ..., 0.01002506,
#          0.25413534, 0.        ]],
#
#        [[0.57142857, 0.87066246, 0.47945205, ..., 0.16090226,
#          0.16390977, 0.04711779]],
#
#        ...,
#
#        [[0.60714286, 0.82649842, 0.50684932, ..., 0.        ,
#          0.01455562, 0.00601504]],
#
#        [[0.51190476, 0.90851735, 0.7260274 , ..., 0.17042607,
#          0.02706767, 0.        ]],
#
#        [[0.53571429, 0.84858044, 0.52054795, ..., 0.        ,
#          0.        , 0.        ]]])

# %%
y_train.shape
# Out:
# (2099,)

# %%
# Part 2 - Building the RNN

# Importing the Keras libraries and packages


from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
# Initialising the RNN
regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (38,1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_13 (LSTM)               (None, 38, 50)            10400
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 38, 50)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 38, 50)            20200
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 38, 50)            0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 38, 50)            20200
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 38, 50)            0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 50)                20200
# ...

# %%
X_train.shape
# Out:
# (2099, 38)

# %%
X_test.shape
# Out:
# (525, 38)

# %%
from numpy import newaxis

# %%
# Reshaping
X_reshape = np.reshape(X_train,(2099,38,1))

# %%
y_train.shape
# Out:
# (2099,)

# %%
X_reshape.shape
# Out:
# (2099, 38, 1)

# %%
# Fitting the RNN to the Training set
regressor.fit(X_reshape, y_train, epochs = 10, batch_size = 20)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 2099/2099 [==============================] - 37s 17ms/step - loss: 0.0104
# Epoch 2/10
# 2099/2099 [==============================] - 30s 14ms/step - loss: 0.0102
# Epoch 3/10
# 2099/2099 [==============================] - 29s 14ms/step - loss: 0.0102
# Epoch 4/10
# 2099/2099 [==============================] - 29s 14ms/step - loss: 0.0102
# Epoch 5/10
# 2099/2099 [==============================] - 30s 14ms/step - loss: 0.0102
# Epoch 6/10
# 2099/2099 [==============================] - 30s 14ms/step - loss: 0.0101
# Epoch 7/10
# 2099/2099 [==============================] - 30s 14ms/step - loss: 0.0101
# Epoch 8/10
# 2099/2099 [==============================] - 30s 14ms/step - loss: 0.0101
# Epoch 9/10
# ...

# %%
X_test2 = np.reshape(X_test,(525,38,1))

# %%
predicted_RR = regressor.predict(X_test2)

# %%
predicted_RR
# Out:
# array([[0.05850615],
#        [0.06503951],
#        [0.06240691],
#        [0.06166533],
#        [0.0601741 ],
#        [0.0683769 ],
#        [0.06509157],
#        [0.06564182],
#        [0.05999549],
#        [0.06089856],
#        [0.06439278],
#        [0.05935182],
#        [0.06878857],
#        [0.06426261],
#        [0.06597081],
#        [0.0601113 ],
#        [0.06277077],
#        [0.06212528],
#        [0.06160303],
#        [0.06945122],
#        [0.06163062],
#        [0.06814814],
#        [0.06248086],
#        [0.06241181],
#        [0.06214291],
#        [0.06368932],
#        [0.0628023 ],
#        [0.06220372],
#        [0.06223076],
#        [0.06139361],
#        [0.0633765 ],
#        [0.06034845],
#        [0.06208257],
#        [0.05978277],
#        [0.05700956],
#        [0.06107038],
#        [0.06337306],
#        [0.06229227],
#        [0.06279723],
#        [0.05935738],
#        [0.05957754],
#        [0.06062784],
#        [0.06042471],
# ...

# %%
X_test.shape
# Out:
# (525, 38)

# %%
predicted_RReal = np.hstack((X_test,predicted_RR))

# %%
predicted_RReal.shape
# Out:
# (525, 39)

# %%
predicted_RReal_2 = sc.inverse_transform(predicted_RReal)

# %%
y_test2 = np.asarray(y_test)

# %%
y_test2 = np.reshape(y_test2,(525,1))

# %%
real_data = np.hstack((X_test,y_test2))

# %%
real_data = sc.inverse_transform(real_data)

# %%
real_data.shape
# Out:
# (525, 39)

# %%
predicted_RReal_2[:,38]
# Out:
# array([11.67197763, 12.97538185, 12.45017903, 12.30223261, 12.00473223,
#        13.6411913 , 12.98576727, 13.09554318, 11.96910047, 12.14926367,
#        12.84635867, 11.84068745, 13.72332034, 12.82039142, 13.16117625,
#        11.99220344, 12.52276842, 12.39399272, 12.28980489, 13.85551846,
#        12.29530826, 13.59555465, 12.46493221, 12.45115559, 12.397511  ,
#        12.7060196 , 12.52905882, 12.40964218, 12.41503704, 12.24802468,
#        12.64361199, 12.03951526, 12.38547347, 11.92666178, 11.37340779,
#        12.18354058, 12.64292528, 12.42730868, 12.52804808, 11.84179704,
#        11.88571914, 12.09525417, 12.05472996, 12.4946682 , 12.12139087,
#        12.67634826, 13.1149049 , 12.42887682, 11.84615736, 12.2087416 ,
#        12.13503891, 12.64069866, 13.58810486, 12.68293149, 11.90231618,
#        12.58735953, 12.07478954, 13.8487747 , 14.02602532, 13.02755566,
#        12.43021086, 13.67415945, 12.2133665 , 12.85712906, 12.26773719,
# ...

# %%
y_array = np.asarray(y_test)

# %%
# Visualising the results
plt.plot(real_data[:,38], color = 'red', label = 'y_test')
plt.plot(predicted_RReal[:,38], color = 'blue', label = 'Predicted RR')
plt.title('Curah hujan')
plt.xlabel('Time')
plt.ylabel('Huehuhue')
plt.legend()
plt.show()

# %%
#HISTOGRAM
#HEATMAP
#SUMMARY BUAT MODEL
#DESCRIBE DAN DESCRIBE.T
#HEAD
#TEST DAN TRAINING
#CORRELATION
#SHAPE INDEX COLUMN
#COUNT SUM MEAN MIN MAX

# %%
y_test
# Out:
# array([6.66666667e-02, 1.69423559e-01, 8.37092732e-02, 1.73934837e-01,
#        1.04260652e-01, 1.00250627e-03, 3.11278195e-01, 0.00000000e+00,
#        4.28129146e-02, 5.51378446e-03, 8.81847476e-02, 2.50626566e-02,
#        6.46616541e-02, 0.00000000e+00, 1.03583960e-01, 9.66363277e-02,
#        4.03007519e-01, 7.59085213e-02, 0.00000000e+00, 1.42333105e-01,
#        1.54385965e-01, 0.00000000e+00, 4.11528822e-01, 1.57393484e-01,
#        5.01253133e-03, 2.80200501e-01, 1.21514312e-01, 1.42333105e-01,
#        3.80952381e-02, 8.02005013e-02, 0.00000000e+00, 5.41353383e-02,
#        0.00000000e+00, 3.00751880e-03, 6.51629073e-03, 0.00000000e+00,
#        1.51879699e-01, 4.93506494e-02, 1.21514312e-01, 0.00000000e+00,
#        1.00250627e-03, 7.61904762e-02, 1.12820513e-01, 0.00000000e+00,
#        0.00000000e+00, 2.96195033e-04, 1.15288221e-02, 4.56140351e-01,
#        6.92024178e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
dataset.columns
# Out:
# Index(['Tn', 'Tx', 'Tavg', 'ddd_x', 'N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW',
#        'C', 'Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Ags', 'Sep',
#        'Okt', 'Nov', 'Des', 'RR_avg_5day', 'RH_avg_5day', 'RH1', 'RH2', 'RH3',
#        'RH_avg', 'ff_x1', 'ff_x2', 'ff_x3', 'ff_x', 'RR1', 'RR2', 'RR3', 'RR'],
#       dtype='object')

# %%
dataX = dataset.drop(['RR'],axis=1)
dataY = dataset.RR

# %%
dataX.shape
# Out:
# (2624, 38)

# %%
dataX_train, dataX_test, dataY_train, dataY_test = train_test_split(dataX, dataY, test_size = 0.20)

# %%
dataX_train = np.asarray(dataX_train)
dataX_test = np.asarray(dataX_test)
dataY_train = np.asarray(dataY_train)
dataY_test = np.asarray(dataY_test)

# %%
dataX_train.shape
# Out:
# (2099, 38)

# %%
dataX_train = np.reshape(dataX_train,(2099,38,1)) 
dataX_test = np.reshape(dataX_test,(525,38,1))

# %%
# Fitting the RNN to the Training set
regressor.fit(dataX_train, dataY_train, epochs = 50, batch_size = 20)
# Out:
# Epoch 1/50
# 2099/2099 [==============================] - 30s 14ms/step - loss: 404.4782
# Epoch 2/50
# 2099/2099 [==============================] - 29s 14ms/step - loss: 394.1896
# Epoch 3/50
# 2099/2099 [==============================] - 30s 14ms/step - loss: 394.9798
# Epoch 4/50
# 2099/2099 [==============================] - 29s 14ms/step - loss: 395.0109
# Epoch 5/50
# 2099/2099 [==============================] - 29s 14ms/step - loss: 394.7391
# Epoch 6/50
# 2099/2099 [==============================] - 29s 14ms/step - loss: 395.0962
# Epoch 7/50
# 2099/2099 [==============================] - 30s 14ms/step - loss: 396.1766
# Epoch 8/50
# 2099/2099 [==============================] - 30s 14ms/step - loss: 395.0950
# Epoch 9/50
# 2099/2099 [==============================] - 30s 14ms/step - loss: 394.2045
# Epoch 10/50
# 2099/2099 [==============================] - 30s 14ms/step - loss: 395.2203
# Epoch 11/50
# ...

# %%
prediksi_RR = regressor.predict(dataX_test)
prediksi_RR
# Out:
# array([[12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
#        [12.458739],
# ...

# %%
prediksi_RR.shape
# Out:
# (525, 1)

# %%
evals = regressor.evaluate(dataY_test,prediksi_RR)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-d3adf4606a7e> in <module>
# ----> 1 evals = regressor.evaluate(dataY_test,prediksi_RR)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps)
#    1100             x, y,
#    1101             sample_weight=sample_weight,
# -> 1102             batch_size=batch_size)
#    1103         # Prepare inputs, delegate logic to `test_loop`.
#    1104         if self._uses_dynamic_learning_phase():
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
# ...

# %%
evals
# Out:
# 420.4625920613607
