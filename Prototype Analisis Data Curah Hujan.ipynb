# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
dataset = pd.read_csv('CSV\Data Murni Missing Value.csv')
dataset.head()
# Out:
#       Tanggal    Tn    Tx  Tavg  RH_avg   ss  ff_x  ddd_x  ff_avg  ddd_car  \
# 0  01-02-2010  24.6  30.2  27.3    82.0  3.6   7.0  220.0     2.0        7
# 1  02-02-2010  24.4  32.0  27.5    79.0  3.8   7.0  230.0     2.0        7
# 2  03-02-2010  24.8  31.5  28.0    81.0  3.8   7.0  240.0     1.0        7
# 3  04-02-2010  25.7  32.6  29.1    80.0  6.2   9.0  200.0     2.0        4
# 4  05-02-2010  25.3  32.4  28.1    80.0  5.9   9.0  240.0     2.0        4
#
#      RR  bulan
# 0   0.6      2
# 1  12.2      2
# 2   2.5      2
# 3   0.8      2
# 4   1.7      2

# %%
dataset.tail()
# Out:
#          Tanggal         Tn         Tx       Tavg  RH_avg      ss      ff_x  \
# 2989  24-05-2019  25.800000  31.400000  27.500000    85.0  10.000  5.000000
# 2990  25-05-2019  24.600000  30.200000  27.100000    80.0   9.500  6.000000
# 2991  26-05-2019  25.000000  30.400000  27.700000    80.0  10.000  4.000000
# 2992  27-05-2019  25.205556  31.221053  27.911111    81.5   8.585  3.952381
# 2993  28-05-2019  25.205556  31.600000  27.600000    85.0   5.800  5.000000
#
#            ddd_x    ff_avg  ddd_car         RR  bulan
# 2989  120.000000  3.000000        3   0.500000      5
# 2990   80.000000  2.000000        3  11.242857      5
# 2991  120.000000  3.000000        4   0.400000      5
# 2992  118.095238  2.142857        3  11.242857      5
# 2993  120.000000  3.000000        4  11.242857      5

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2994 entries, 0 to 2993
# Data columns (total 12 columns):
# Tanggal    2994 non-null object
# Tn         2992 non-null float64
# Tx         2986 non-null float64
# Tavg       2994 non-null float64
# RH_avg     2993 non-null float64
# ss         2698 non-null float64
# ff_x       2993 non-null float64
# ddd_x      2993 non-null float64
# ff_avg     2994 non-null float64
# ddd_car    2994 non-null int64
# RR         2993 non-null float64
# bulan      2994 non-null int64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 280.8+ KB

# %%
dataset.shape
# Out:
# (2994, 12)

# %%
dfna = dataset[dataset.isna().any(axis=1)]

# %%
dfna
# Out:
#          Tanggal         Tn         Tx       Tavg     RH_avg         ss  \
# 631   01-11-2011  24.600000  29.800000  26.900000  87.000000   4.700000
# 1235  01-01-2014  25.000000  31.564286  28.078571  79.428571        NaN
# 1236  02-01-2014  25.000000  31.564286  29.300000  77.000000        NaN
# 1237  03-01-2014  24.800000  32.200000  29.300000  76.000000        NaN
# 1238  04-01-2014  25.100000  31.564286  28.500000  78.000000        NaN
# 1239  05-01-2014  25.600000  28.000000  25.500000  91.000000        NaN
# 1240  06-01-2014  24.500000  30.200000  27.800000  80.000000        NaN
# 1241  07-01-2014  24.200000  31.500000  29.300000  77.000000        NaN
# 1242  08-01-2014  23.800000  31.200000  28.078571  79.428571        NaN
# 1243  09-01-2014  24.600000  31.800000  29.000000  76.000000        NaN
# 1244  10-01-2014  24.600000  30.700000  28.900000  81.000000        NaN
# 1245  11-01-2014  25.000000  31.900000  28.900000  77.000000        NaN
# ...

# %%
dataset.describe()
# Out:
#                 Tn           Tx         Tavg       RH_avg           ss  \
# count  2992.000000  2986.000000  2994.000000  2993.000000  2698.000000
# mean     24.505977    30.965473    27.266236    82.777318     6.054715
# std       0.985812     1.607891     1.128262     4.078171     5.080307
# min      18.000000     3.600000    23.200000    41.000000     0.000000
# 25%      24.000000    30.000000    26.600000    80.000000     4.100000
# 50%      24.600000    31.200000    27.400000    83.000000     6.304000
# 75%      25.196000    32.100000    28.000000    85.000000     8.000000
# max      27.900000    36.000000    30.700000    97.000000    99.000000
#
#               ff_x        ddd_x       ff_avg      ddd_car           RR  \
# count  2993.000000  2993.000000  2994.000000  2994.000000  2993.000000
# mean      6.103019   165.591057     2.180017     3.746159    12.668625
# std       2.474101    66.803313     1.092203     2.319104    20.138644
# ...

# %%
dataset.describe().T
# Out:
#           count        mean        std   min    25%      50%      75%    max
# Tn       2992.0   24.505977   0.985812  18.0   24.0   24.600   25.196   27.9
# Tx       2986.0   30.965473   1.607891   3.6   30.0   31.200   32.100   36.0
# Tavg     2994.0   27.266236   1.128262  23.2   26.6   27.400   28.000   30.7
# RH_avg   2993.0   82.777318   4.078171  41.0   80.0   83.000   85.000   97.0
# ss       2698.0    6.054715   5.080307   0.0    4.1    6.304    8.000   99.0
# ff_x     2993.0    6.103019   2.474101   0.0    4.0    6.000    8.000   36.0
# ddd_x    2993.0  165.591057  66.803313   0.0  120.0  140.000  220.000  360.0
# ff_avg   2994.0    2.180017   1.092203   0.0    1.0    2.000    3.000    7.0
# ddd_car  2994.0    3.746159   2.319104   1.0    1.0    4.000    5.000    9.0
# RR       2993.0   12.668625  20.138644   0.0    0.2    5.100   17.230  199.5
# bulan    2994.0    6.316967   3.466040   1.0    3.0    6.000    9.000   12.0

# %%
dataset.corr()
# Out:
#                Tn        Tx      Tavg    RH_avg        ss      ff_x     ddd_x  \
# Tn       1.000000  0.443748  0.662170 -0.017968 -0.037837 -0.195813  0.154951
# Tx       0.443748  1.000000  0.715858 -0.221799 -0.061212 -0.171196  0.365644
# Tavg     0.662170  0.715858  1.000000 -0.389856  0.007928 -0.231979  0.214992
# RH_avg  -0.017968 -0.221799 -0.389856  1.000000 -0.136548 -0.104746 -0.045063
# ss      -0.037837 -0.061212  0.007928 -0.136548  1.000000 -0.018418 -0.121329
# ff_x    -0.195813 -0.171196 -0.231979 -0.104746 -0.018418  1.000000 -0.007539
# ddd_x    0.154951  0.365644  0.214992 -0.045063 -0.121329 -0.007539  1.000000
# ff_avg  -0.242697 -0.400577 -0.316323 -0.161463  0.144085  0.487313 -0.307740
# ddd_car  0.031436  0.126664  0.037593 -0.096048 -0.088184  0.209737  0.226439
# RR      -0.039308  0.051634 -0.007627  0.280164 -0.078284 -0.118391  0.071094
# bulan   -0.137554 -0.393921 -0.272110  0.113265  0.020510  0.051803 -0.288748
#
# ...

# %%
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
dataset.corr().style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col0 {
#             color:  black;
#         }    #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col1 {
#             color:  black;
#         }    #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col2 {
#             color:  black;
#         }    #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col3 {
#             color:  red;
#         }    #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col4 {
#             color:  red;
#         }    #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col5 {
#             color:  red;
#         }    #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col6 {
#             color:  black;
#         }    #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col7 {
#             color:  red;
#         }    #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col8 {
#             color:  black;
#         }    #T_b7151276_2a21_11ea_b36c_04d4c4763154row0_col9 {
#             color:  red;
# ...

# %%
dataset.hist(figsize = (20,20))
plt.show()

# %%
dataset['Target'] = dataset.RR
C_mat = dataset.corr()
fig = plt.figure(figsize = (10,10))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
datasetcoba = dataset
datasetcoba.head()
# Out:
#       Tanggal    Tn    Tx  Tavg  RH_avg   ss  ff_x  ddd_x  ff_avg  ddd_car  \
# 0  01-02-2010  24.6  30.2  27.3    82.0  3.6   7.0  220.0     2.0        7
# 1  02-02-2010  24.4  32.0  27.5    79.0  3.8   7.0  230.0     2.0        7
# 2  03-02-2010  24.8  31.5  28.0    81.0  3.8   7.0  240.0     1.0        7
# 3  04-02-2010  25.7  32.6  29.1    80.0  6.2   9.0  200.0     2.0        4
# 4  05-02-2010  25.3  32.4  28.1    80.0  5.9   9.0  240.0     2.0        4
#
#      RR  bulan
# 0   0.6      2
# 1  12.2      2
# 2   2.5      2
# 3   0.8      2
# 4   1.7      2

# %%
datasetcoba["ss"].fillna(method='ffill',inplace=True)

# %%
dataset.fillna(method='ffill',inplace=True)

# %%
dataset[dataset.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Tanggal, Tn, Tx, Tavg, RH_avg, ss, ff_x, ddd_x, ff_avg, ddd_car, RR, bulan, Target]
# Index: []

# %%
dataset.describe().T
# Out:
#           count        mean        std   min    25%    50%      75%    max
# Tn       2994.0   24.506205   0.985564  18.0   24.0   24.6   25.196   27.9
# Tx       2994.0   30.966334   1.607240   3.6   30.0   31.2   32.100   36.0
# Tavg     2994.0   27.266236   1.128262  23.2   26.6   27.4   28.000   30.7
# RH_avg   2994.0   82.774720   4.079966  41.0   80.0   83.0   85.000   97.0
# ss       2994.0    6.093294   4.901863   0.0    4.2    6.4    8.000   99.0
# ff_x     2994.0    6.103987   2.474254   0.0    4.0    6.0    8.000   36.0
# ddd_x    2994.0  165.575830  66.797349   0.0  120.0  140.0  220.000  360.0
# ff_avg   2994.0    2.180017   1.092203   0.0    1.0    2.0    3.000    7.0
# ddd_car  2994.0    3.746159   2.319104   1.0    1.0    4.0    5.000    9.0
# RR       2994.0   12.664561  20.136507   0.0    0.2    5.1   17.230  199.5
# bulan    2994.0    6.316967   3.466040   1.0    3.0    6.0    9.000   12.0
# ...

# %%
dataset[dataset.Tx<=20]
# Out:
#          Tanggal    Tn   Tx  Tavg  RH_avg   ss  ff_x  ddd_x  ff_avg  ddd_car  \
# 2432  13-05-2017  25.3  3.6  27.6    79.0  8.3   7.0  130.0     2.0        3
#
#         RR  bulan  Target
# 2432  19.4      5    19.4

# %%
dataset = dataset.drop(dataset.index[2432])

# %%
dataset[dataset.Tx<=20]
# Out:
# Empty DataFrame
# Columns: [Tanggal, Tn, Tx, Tavg, RH_avg, ss, ff_x, ddd_x, ff_avg, ddd_car, RR, bulan, Target]
# Index: []

# %%
datasetcoba.ss
# Out:
# 0        3.600000
# 1        3.800000
# 2        3.800000
# 3        6.200000
# 4        5.900000
# 5        0.100000
# 6        3.300000
# 7        5.900000
# 8        5.400000
# 9        8.000000
# 10       4.100000
# 11       3.900000
# 12       2.600000
# 13       5.100000
# 14       7.300000
# 15       8.000000
# 16       3.800000
# 17       7.500000
# 18       0.000000
# 19       1.400000
# 20       7.400000
# 21       6.100000
# 22       8.000000
# 23       4.000000
# 24       4.200000
# 25       7.500000
# 26       5.900000
# 27       5.800000
# 28       6.100000
# 29       6.600000
#           ...
# 2964     8.300000
# 2965     7.195455
# 2966     9.800000
# 2967     9.900000
# 2968     5.500000
# 2969     8.585000
# 2970     8.585000
# 2971     9.500000
# 2972     7.000000
# 2973     8.300000
# 2974     8.100000
# 2975     8.585000
# 2976     7.000000
# 2977     8.585000
# 2978     8.585000
# 2979     9.100000
# 2980     8.585000
# 2981     8.100000
# 2982     9.500000
# ...

# %%
datasetcoba.isnull()
# Out:
#       Tanggal     Tn     Tx   Tavg  RH_avg     ss   ff_x  ddd_x  ff_avg  \
# 0       False  False  False  False   False  False  False  False   False
# 1       False  False  False  False   False  False  False  False   False
# 2       False  False  False  False   False  False  False  False   False
# 3       False  False  False  False   False  False  False  False   False
# 4       False  False  False  False   False  False  False  False   False
# 5       False  False  False  False   False  False  False  False   False
# 6       False  False  False  False   False  False  False  False   False
# 7       False  False  False  False   False  False  False  False   False
# 8       False  False  False  False   False  False  False  False   False
# 9       False  False  False  False   False  False  False  False   False
# 10      False  False  False  False   False  False  False  False   False
# 11      False  False  False  False   False  False  False  False   False
# ...
